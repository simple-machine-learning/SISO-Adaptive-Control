# %% [markdown]
# # SISO Adaptive Control — metodologické poznámky
#
# Datově řízená identifikace a řízení systémů s jedním vstupem a jedním výstupem (SISO) pomocí lineární neuronové jednotky (LNU), kvadratické neuronové jednotky (QNU), viz např. [1-4], a případně vícevrstvé perceptron sítě (MLP), s využitím metody hlavních komponent (PCA), řízení s referenčním modelem (MRAC) a prediktivním řízením (MPC) se strojovým učením. Fyzikální modely (diferenciální rovnice) jsou využity jen jako příklady řízených soustav; slouží jen k simulaci dat a simulaci řízeného systému a k návrhu řízení jsou použita jen jejich měřená (simulovaná) data.
#
# ## Praktická volba neuronového architektury a nastavení
#
# Důraz je kladen na vztah mezi vzorkováním, délkou historie, pracovní oblastí dat, rekurzivním provozem dynamického modelu, spektrálními diagnostikami a dosažitelností požadované regulace.
#
# ---
# Pozn.: Ukázky nutně nereprezentují nejlepší možné nalezené konfgurace které je možno pro daný systém dosáhnout.

# %% [markdown]
# # 1. Co musí být ověřeno před návrhem regulátoru
#
# Nízká chyba jednokroková predikce sama o sobě nemusí stačit. Pro použití je vhodné posoudit i
# - chování dynamického modelu při rekurzivní vícekrokové predikci;
# - pokrytí pracovní oblasti akční veličiny $u$ která je jediným vstupem v tréninkových datech;
# - pokrytí pracovního rozsahu regulované veličiny $y$ a průběhu žádané veličiny $d$;
# - dynamickou stabilitu naučeného neuronovéh modelu, ideálně $\rho (\textbf{A}_y(k))<1$ pro LNU a QNU, a $\rho(J_y)<1$ pro MLP pro co nejvíce datových vzorků, ideálně $ \forall k$  viz např. [1];
# - numerickou stabilitu učení $\rho (\textbf{A}_w(k))<1$,, viz např. [2,3].

# %% [markdown]
# # 2. Pracovní oblast $u$, $d$, $y$ a dosažitelnost reference
#
# Při identifikaci je vhodné mít zvolený rozsah $u$, $d$ a $y$ reprezentativní pro očekávaný provoz.
#
# Je vhodné porovnat oblast použitou při trénování s oblastí požadovanou při regulaci:
#
# $$
# u_{\mathrm{train}},\ d_{\mathrm{train}},\ y_{\mathrm{train}}
# \quad \leftrightarrow \quad
# u_{\mathrm{control}},\ d_{\mathrm{control}},\ y_{\mathrm{ref}}.
# $$
#
# Požadovaná reference může být nedosažitelná amplitudově, pokud dostupný rozsah $u$ nestačí, nebo dynamicky, pokud referenční model požaduje odezvu, kterou soustava a aktuátor nemohou realizovat.
#
# U MRAC i MPC je dosažitelnost referenčního modelu, tj. požadovaného chování celého řízeného systému zásadní. Lze rozlišovat:
# - **amplitudovou dosažitelnost** — zda regulovaný systém může vůbec dosáhnout požadované hodnoty $y$;
# - **dynamickou dosažitelnost** —  zda regulovaný systém může dosáhnout požadované rychlosti, tlumení a tvaru odezvy definované referenčním modelem nebo jinak předepisovaným způsobem.
#
# U MRAC musí být referenční model zvolen tak, aby jeho dynamika byla dosažitelná vzhledem k dynamice soustavy, omezenému rozsahu akční veličiny a tomu, co se regulátor může z dostupných dat a zvolené struktury naučit. Příliš rychlý, málo tlumený nebo jinak nerealistický referenční model může vést k trvalé regulační chybě, saturaci akční veličiny nebo nestabilní adaptaci.
#
# U MPC lze omezení $u$ zahrnout přímo do optimalizace, ale ani MPC nemůže překonat fyzikální nedosažitelnost nebo nedostatečně naučenou pracovní oblast.

# %% [markdown]
# # 3. Volba vzorkovací periody $dt$
#
# Vzorkovací perioda $dt$ musí zachytit nejrychlejší jevy relevantní pro predikci a řízení.
#
# Příliš velké $dt$ může skrýt rychlé přechody, zhoršit reprezentaci kmitání a sloučit dopravní zpoždění do několika málo vzorků.
#
# Příliš malé $dt$ může vytvářet silně korelované sousední vzorky, vyžadovat větší $n_u$ a $n_y$, zvětšit dimenzi regresoru, zvýraznit šum a zhoršit numerickou podmíněnost.
#
# Praktickým cílem je zvolit největší $dt$, které ještě zachovává dynamiku významnou pro regulaci.

# %% [markdown]
# # 4. Volba $n_u$ a $n_y$
#
# Parametry $n_u$ a $n_y$ určují délku historie vstupu a výstupu:
#
# $$
# T_u = n_u \cdot dt, \qquad T_y = n_y \cdot dt  \ \ \ [sec].
# $$
#
# Historie má pokrýt dopravní zpoždění, relevantní dynamickou paměť a podstatnou část kmitavého průběhu.
#
# Příliš krátká historie neobsahuje potřebnou informaci. Příliš dlouhá historie zvyšuje počet parametrů, kolinearitu a riziko přeučení.
#
# Začněte menšími hodnotami $n_u$ a $n_y$ a historii prodlužujte pouze tehdy, pokud se zlepšuje jednokroková predikce, rekurzivní vícekroková predikce a regulační použitelnost.

# %% [markdown]
# # 5. Linear Neural Unit (LNU)
#
# LNU má být výchozí model. LNU a QNU patří mezi neuronové architektury (Higher-Order Neural Units, HONU), jejichž učení je lineární v adaptovaných parametrech [1], [2].
#
# To platí i pro mnoho fyzikálně nelineárních systémů. V omezené pracovní oblasti může být vstupně-výstupní dynamika dostatečně dobře aproximovatelná afinně-lineárním dynamickým modelem.
#
# LNU naučená dávkovou metodou na celém tréninkovém souboru často pro řízení postačuje, i když QNU poskytuje přesnější identifikaci.
#
# Pro řízení je důležité, aby model dostatečně zachytil znaménko a velikost účinku vstupu, dynamickou paměť, zpoždění, pracovní rozsah $u$ a $y$ a chování při rekurzivním provozu.
#
# Vyšší přesnost identifikace složitějšího modelu nemusí znamenat lepší regulační výsledek.

# %% [markdown]
# # 6. Quadratic Neural Unit (QNU)
#
# QNU je vhodné použít především tehdy, když LNU neposkytuje dostatečnou kvalitu identifikace nebo regulace ve zvolené pracovní oblasti. QNU rozšiřuje LNU o kvadratické a interakční členy při zachování linearity v adaptovaných vahách [1], [2].
#
# QNU může být výhodná u asymetrických systémů, amplitudově závislé dynamiky, nelineárního tření, stavově závislého zesílení a interakcí mezi zpožděnými vstupy a výstupy.
#
# U nesymetrických modelů může QNU identifikovat výrazně lépe než LNU. Pro samotné řízení však často postačuje LNU, pokud dostatečně zachycuje relevantní dynamiku.
#
# QNU zvyšuje dimenzi regresoru a může zhoršit numerickou podmíněnost. Její přínos je nutné posuzovat podle rekurzivní predikce a regulačního chování, nikoli pouze podle tréninkové chyby.

# %% [markdown]
# # 7. Multilayer Perceptron (MLP)
#
# MLP je v MPC používán jako alternativní prediktivní model rostliny.
#
# Je vhodný zejména pro srovnání a pro případy, kdy LNU ani QNU nestačí. U testovaných simulovaných systémů nebyl MLP pro dosažení použitelné regulace nutný.
#
# To odpovídá tomu, že regulace probíhala v omezených pracovních oblastech, LNU často dostatečně zachytila lokální vstupně-výstupní dynamiku a historie v regresoru zachytila významnou část paměti systému.
#
# MLP má vyšší aproximační kapacitu, ale také vyšší nároky na data, architekturu, inicializaci, validaci a rekurzivní provoz.

# %% [markdown]
# # 8. Principal Component Analysis (PCA)
#
# PCA je v tomto softwaru součástí MPC a používá se pro redukci prediktivního regresoru. V MRAC použita není.
#
# Její hlavní význam spočívá v omezení kolinearity a nadměrné dimenze regresoru. Kolinearita vzniká zejména tehdy, když:
#
# - je $dt$ malé a sousední vzorky jsou velmi podobné;
# - jsou $n_u$ nebo $n_y$ větší;
# - QNU vytváří velké množství vzájemně závislých kvadratických a interakčních členů.
#
# V MPC lze počet hlavních komponent volit dvěma způsoby:
#
# - **podle vysvětlené variability** — zachová se nejmenší počet komponent potřebný k dosažení zvoleného podílu variability;
# - **podle hodnosti (hodnosti)** — počet komponent se omezí podle numerické hodnosti datového regresoru.
#
# PCA může:
#
# - odstranit lineárně závislé nebo téměř závislé směry;
# - snížit efektivní dimenzi prediktivního modelu;
# - zlepšit numerickou podmíněnost učení a optimalizace MPC;
# - omezit redundanci způsobenou jemným $dt$ a delší historií;
# - výrazně zmenšit QNU regresor.
#
# V MPC obvykle není důvod PCA automaticky vypínat, zejména u rozsáhlejších nebo kolineárních regresorů. Je však nutné ověřit, že zvolená redukce nezhoršila rekurzivní vícekrokovou predikci a neodstranila směry důležité pro účinek akční veličiny na výstup.
#
# PCA nenahrazuje správnou volbu $dt$, $n_u$ a $n_y$. Pokud historie neobsahuje potřebnou dynamickou informaci, PCA ji nemůže doplnit.

# %% [markdown]
# # 9. Jednokroková predikce a rekurzivní provoz dynamického HONU modelu
#
# Při jednokrokovou predikci jsou v regresoru použity měřené minulé výstupy. Chyba se proto v každém kroku koriguje skutečným měřením.
#
# Při rekurzivní vícekrokové predikci jsou predikované výstupy vraceny zpět do regresoru. Model je tak provozován jako dynamický rekurentní HONU model.
#
# Nízká chyba jednokrokové predikce nezaručuje kvalitní vícekrokovou predikci. Malá lokální chyba se může v rekurzi akumulovat a model může být přesný při identifikaci, ale nevhodný pro MPC.

# %% [markdown]
# # 10. Význam $\rho(A_y)$ a $\rho(J_y)$
#
# Spektrální poloměr $\rho(A_y)$, případně $\rho(J_y(k))$, slouží k posouzení **lokální dynamické stability učící se neuronové architektury**.
#
# Pro LNU je $A_y$ lokální matice dynamiky neuronové architektury. U QNU se první řádek lokální matice dynamiky $A_y(k)$ určuje analyticky a její koeficienty v čase proto závisejí na aktuálním regresoru. U MLP se analogicky používá lokální Jacobian výstupní rekurze $J_y(k)$ získaný derivací sítě v pracovním bodě, tj. v čase $k$.
#
# $$
# \rho(A_y)=\max_i\left|\lambda_i(A_y)\right|.
# $$
#
# - $\rho<1$ indikuje lokálně stabilní rekurzivní výstupní dynamiku;
# - $\rho\approx1$ indikuje hraniční nebo slabě tlumené chování;
# - $\rho>1$ indikuje lokálně nestabilní rekurzivní dynamiku modelu.
#
# Tato implementovaná diagnostika se vztahuje k naučenému modelu a naznačuje vhodnost natrénovaného neuronového modelu k nátrénování a ověření řízení. Sama o sobě není důkazem globální stability fyzikální soustavy ani uzavřené regulační smyčky [1], [2], ale významně k posouzení stability prakticky přispívá.

# %% [markdown]
# # 11. Vztah $\rho(A_y)$ k natrénovatelnosti regulace
#
# $\rho(A_y)$ ovlivňuje natrénovatelnost regulace nepřímo.
#
# Pokud je rekurzivní model lokálně expanzivní, mohou při vícekrokové predikci růst predikční chyba, sensitivities vůči budoucím vstupům, gradienty regulačního kritéria a numerická citlivost optimalizace. To může ztížit učení MRAC regulátoru i optimalizaci MPC.
#
# Naopak $\rho(A_y) < 1$ samo o sobě nezaručuje dobrou natrénovatelnost regulátoru. Problém může být ve slabé citlivosti výstupu na vstup, nedostatečné excitaci, nevhodném referenčním modelu, špatném škálování, nepokryté pracovní oblasti $u$, $d$ a $y$, krátké historii, nevhodném horizontu nebo aktivních omezeních.

# %% [markdown]
# # 12. MRAC — kdy a proč
#
# HONU architektura pro diskrétní MRAC a její dávkové i průběžné učení jsou popsány v [3]. MRAC je obecně výpočetně jednodušší a rychlejší než MPC, protože v každém vzorkovacím kroku neřeší optimalizační úlohu na konečném horizontu.
#
# MRAC je vhodný zejména tehdy, když lze definovat dosažitelný referenční model, nejsou rozhodující explicitní omezení budoucího průběhu, je požadována online adaptace a je důležitá nízká výpočetní náročnost.
#
# U online adaptivní MRAC větve se regulátor během řízení průběžně učí. Váhy regulátoru se dále aktualizují podle regulační chyby a aktuálního chování systému.
#
# Dosažitelnost referenčního modelu musí být posouzena vzhledem k rozsahu $u$, rozsahu poruchy $d$, pracovní oblasti $y$ a dynamickým možnostem soustavy a aktuátoru.

# %% [markdown]
# <!-- GUIDE_FIGURE -->
# ### Ilustrace: MRAC a lokální diagnostika uzavřené smyčky
#
# U LNU-LNU MRAC lze vedle diagnostiky rekurzivního modelu vyhodnocovat také $\rho(M)$ pro lokální stabilitu uzavřené smyčky. Interpretace musí respektovat, že regulátor se při online adaptaci dále mění.
#
# ### MRAC na nelineárním modelu
#
# ### Plant
# <center><img src="Process%20bidirectional-pump%20nonlinear%20tank/plant.jpg" width=80%" >
# </img> </center>
#
# ### MRAC LNU LNU na nelineárním modelu
#
# <center><img src="Process%20bidirectional-pump%20nonlinear%20tank/MRAC/process_bidirectional_pump_nonlinear_tank__mrac__lnu_lnu_detail.png" width=80%" >
# </img> </center>
#
# ### MRAC QNU QNU na tomtéž nelineárním modelu
#
# <center><img src="Process%20bidirectional-pump%20nonlinear%20tank/MRAC/process_bidirectional_pump_nonlinear_tank__mrac__qnu_qnu_detail.png" width=80%" >
# </img> </center>
#
# ### MPC LNU na tomtéž nelineárním modelu
#
# <center><img src="Process%20bidirectional-pump%20nonlinear%20tank/MPC/process_bidirectional_pump_nonlinear_tank__mpc__lnu_lnu_detail.png" width=80%" >
# </img> </center>

# %% [markdown]
# # 13. MPC — kdy a proč
#
# MPC je vhodnější tehdy, když je nutné explicitně pracovat s dopravním zpožděním, predikčním horizontem, omezením $u$, omezením rychlosti změny $u$, budoucí referencí nebo kompromisem mezi sledováním reference a akčním zásahem.
#
# MPC podporuje prediktivní modely LNU, QNU a MLP.
#
# MPC je flexibilnější než MRAC, ale za cenu vyšší výpočetní náročnosti a většího počtu parametrů k ladění. Dlouhý horizont není automaticky výhodný; u rekurzivně citlivého modelu může zhoršit optimalizaci i regulační výsledek.

# %% [markdown]
# <!-- GUIDE_FIGURE -->
# ### Ilustrace: MPC u kmitavého systému s dopravním zpožděním
#
# U kmitavé soustavy se zpožděním umožňuje MPC pracovat s historií, predikčním horizontem a omezením akční veličiny v jedné optimalizační úloze.
#
# ### Plant
#
# <center><img src="Mechanical%20overhead%20crane%20payload%20sway%20with%20delay/plant.jpg" width=80%" >
# </img> </center>
#
#
# ### MPC LNU
#
# <center><img src="Mechanical%20overhead%20crane%20payload%20sway%20with%20delay/MPC/mechanical_overhead_crane_payload_sway_with_delay__mpc__lnu.png" width=80%" >
# </img> </center>
#
# <br>
#
# <center><img src="Mechanical%20overhead%20crane%20payload%20sway%20with%20delay/MPC/mechanical_overhead_crane_payload_sway_with_delay__mpc__lnu_detail.png" width=80%" >
# </img> </center>

# %% [markdown]
# # 14. MRAC versus MPC — praktické rozhodnutí
#
# **MRAC** preferujte, když je prioritou jednoduchost, rychlost, online adaptace a existuje realisticky dosažitelný referenční model.
#
# **MPC** preferujte, když jsou zásadní zpoždění, omezení $u$, budoucí reference nebo explicitní kompromis mezi regulační chybou a akčním zásahem.
#
# Fyzikální třída systému sama o sobě volbu nemusí určovat. Rozhodující je dosažitelnost reference, pokrytí pracovní oblasti $u$, $d$ a $y$, význam zpoždění $\tau_u$, omezení aktuátoru, kvalita rekurzivního naučeného modelu a dostupný výpočetní výkon.
#
# Vybrané výsledky ilustrují použití MRAC u servomechanismů, biomedicínských, ekologických a procesních systémů a použití MPC zejména u zpožděných mechanických, síťových a energetických systémů.

# %% [markdown]
# # 15. Bias členy $x_0$ a $\xi_0$
#
# Bias člen $x_0$ v modelu soustavy a bias člen $\xi_0$ v regulátoru umožňují afinní, nikoli pouze čistě lineární mapování.
#
# U LNU modelu soustavy:
#
# $$
# \hat y(k) = w_0 + \mathbf{w}^{\mathsf T}\mathbf{x}(k).
# $$
#
# U LNU regulátoru:
#
# $$
# u(k) = v_0 + \mathbf{v}^{\mathsf T}\boldsymbol{\xi}(k).
# $$
#
# Bias umožňuje reprezentovat nenulový pracovní bod, statický offset, asymetrickou pracovní oblast, nenulovou ustálenou složku akčního zásahu a kompenzaci konstantní poruchy.
#
# Bias sám o sobě není integrátor. U MRAC však bias regulátoru $\xi_0$ může umožnit naučení konstantní ustálené korekce, která pomáhá zmenšit trvalou regulační odchylku.

# %% [markdown]
# # 16. Úloha P-regulátoru
#
# P-regulátor může tvořit jednoduchou základní stabilizační vrstvu.
#
# Může rychle reagovat na regulační chybu, zvýšit efektivní tlumení, omezit odchylky od pracovního bodu, omezit pohyb do silně nelineárních oblastí, usnadnit činnost MRAC nebo MPC a sloužit jako diagnostický referenční základ.
#
# P-regulátor nelinearity neodstraňuje, ale může omezit jejich praktický vliv tím, že systém udržuje v užší pracovní oblasti.
#
# Ve spojení s MRAC nebo MPC může P-větev stabilizovat základní dynamiku, zatímco adaptivní nebo prediktivní část vytváří doplňkový akční zásah. Tato kombinace může zmenšit trvalou regulační odchylku, zejména pokud adaptivní nebo prediktivní část dokáže vytvořit nenulovou ustálenou složku $u$.
#
# Samotný P-regulátor odstranění trvalé odchylky obecně nezaručuje.

# %% [markdown]
# # 17. Rozšíření na PI nebo PID
#
# Základní stabilizační větev lze rozšířit z P-regulátoru na PI nebo PID.
#
# - **P složka** poskytuje okamžitou stabilizační reakci.
# - **I složka** akumuluje regulační chybu a může odstranit trvalou regulační odchylku.
# - **D složka** může zvýšit tlumení rychlých a kmitavých přechodů.
#
# MRAC nebo MPC pak může pracovat nad základní PI/PID stabilizační vrstvou a zlepšovat dynamické chování v rámci naučené pracovní oblasti.
#
# Při použití PI/PID je nutné zohlednit anti-windup při saturaci, filtraci derivační složky, vliv zpoždění a interakci mezi adaptivní/prediktivní a základní regulační větví.
#
# Verze v1.0.0 implementuje pouze P-regulátor.

# %% [markdown]
# # 18. Doporučený pracovní postup
#
# 1. Vymezit očekávaný rozsah $u$, $d$ a $y$.
# 2. Zvolit $dt$ podle nejrychlejšího relevantního jevu.
# 3. Nastavit malé historie embedingů $n_u$ a $n_y$ (cca 3-10).
# 4. Natrénovat dávkově naučenou LNU; v MRAC nebo MPC,  v MPC ověřit vhodnost nastavení PCA.
# 5. Vyhodnotit přesnost naučení neuronového modelu soustavy.
# 7. Zkontrolovat $\rho(A_y)$ nebo $\rho(J_y)$ v celém časovém průběhu (ideálně <1).
# 8. Prodloužit historii embedingů pouze při prokazatelném zlepšení.
# 9. V MPC nastavit PCA podle vysvětlené variability nebo podle hodnosti regresoru a ověřit predikci po redukci.
# 10. Zkusit QNU nebo MLP, pokud LNU systematicky nestačí.
# 11. MLP použít pro srovnání nebo při prokázané potřebě.
# 12. Ověřit dosažitelnost referenčního modelu.
# 13. U MPC nastavit omezení $u$, horizont a penalizace.
# 14. Porovnat výsledek s aplikovaným P-regulátorem.

# %% [markdown]
# # 19. Shrnutí
#
# Pro většinu úloh je vhodné začít jednoduchou konfigurací: rozumné $dt$, krátká historie, dávkově naučenou LNU; v MPC následně ověřit variantu s PCA a pracovní oblast tréninkových dat odpovídající očekávanému řízení.
#
# QNU má být použita hlavně tehdy, když LNU prokazatelně nestačí. MLP je vhodný zejména pro srovnání nebo pro případy vyžadující vyšší nelineární aproximační kapacitu.
#
# MRAC je rychlejší a jednodušší, ale vyžaduje dosažitelný referenční model. MPC je vhodnější při zpoždění, omezeních a explicitní práci s budoucím horizontem pro ustálenější průběhy regulované veličiny.
#
# P/PI/PID větev může tvořit základní stabilizační vrstvu, zatímco MRAC nebo MPC zlepšuje chování systému.
#
# Žádná jediná metrika, včetně $\rho(A_y)$, nenahrazuje společné posouzení identifikace, rekurzivní dynamiky, pracovní oblasti, dosažitelnosti reference a regulačního výsledku.

# %% [markdown]
# # 20. Simulované modely soustav a jejich zdrojové citace
#
# ## Bioprocesy a biomedicína
#
# - Bioproces: bioreaktor s řízením rozpuštěného kyslíku. <a href="#ref-5">[5]</a>
# - Bioproces: fotobioreaktor pH / CO2. <a href="#ref-6">[6]</a>
# - Bioproces: biomasa v chemostatu podle Monodova modelu. <a href="#ref-7">[7]</a>
# - Biomedicína: nelineární farmakokinetika léčiva (PK). <a href="#ref-8">[8]</a>
# - Biomedicína: nelineární farmakokineticko-farmakodynamický model (PK-PD). <a href="#ref-9">[9]</a>
# - Biomedicína: model glukóza–inzulin. <a href="#ref-10">[10]</a>
#
# ## Tepelné, IT, síťové a bezdrátové systémy
#
# - Tepelný systém: asymetrický Peltierův článek. <a href="#ref-11">[11]</a>
# - IT: tepelné řízení CPU ventilátorem. <a href="#ref-12">[12]</a>
# - IT: zatížení cloudového serveru. <a href="#ref-13">[13]</a>
# - IT: zatížení cloudového serveru se zpožděním. <a href="#ref-13">[13]</a>, <a href="#ref-14">[14]</a>
# - Síť: nelineární fluidní model fronty směrovače. <a href="#ref-15">[15]</a>
# - Síť: fluidní model fronty směrovače se zpožděním. <a href="#ref-15">[15]</a>, <a href="#ref-14">[14]</a>
# - Síť: fluidní model fronty směrovače s velkým zpožděním. <a href="#ref-15">[15]</a>, <a href="#ref-14">[14]</a>
# - Bezdrátový systém: řízení vysílacího výkonu / SNR. <a href="#ref-16">[16]</a>
#
# ## Procesní a mechanické systémy
#
# - Proces: nelineární nádrž s obousměrným čerpadlem. <a href="#ref-17">[17]</a>
# - Mechanika: dvě hmoty s viskózním tlumením. <a href="#ref-18">[18]</a>
# - Mechanika: dvě hmoty s LuGre třením. <a href="#ref-19">[19]</a>
# - Mechanika: dvě hmoty s LuGre třením 2. <a href="#ref-19">[19]</a>
# - Mechanika: laděný hmotový tlumič vibrací. <a href="#ref-20">[20]</a>
# - Mechanika: servo s kmitací cívkou. <a href="#ref-21">[21]</a>
# - Mechanika: kývání břemene portálového jeřábu. <a href="#ref-22">[22]</a>
# - Mechanika: kývání břemene portálového jeřábu se zpožděním. <a href="#ref-22">[22]</a>, <a href="#ref-14">[14]</a>
#
# ## Letecké, urychlovačové a energetické systémy
#
# - Dron: výška kvadrokoptéry. <a href="#ref-23">[23]</a>
# - Dron: náklon kvadrokoptéry. <a href="#ref-23">[23]</a>
# - Urychlovač: amplituda RF dutiny. <a href="#ref-24">[24]</a>
# - Urychlovač: amplituda RF dutiny se zpožděním. <a href="#ref-24">[24]</a>, <a href="#ref-14">[14]</a>
# - Urychlovač: příčná poloha svazku. <a href="#ref-25">[25]</a>
# - Elektrizační soustava: lineární frekvence mikrosítě. <a href="#ref-26">[26]</a>
# - Elektrizační soustava: nelineární frekvence mikrosítě s BESS. <a href="#ref-27">[27]</a>
# - Elektrizační soustava: nelineární frekvence mikrosítě s BESS a zpožděním. <a href="#ref-27">[27]</a>, <a href="#ref-14">[14]</a>
#
# ## Půdní ekologie
#
# - Půdní ekologie: respirace řízená vlhkostí. <a href="#ref-28">[28]</a>
# - Půdní ekologie: vlhkostně řízená respirace se zpožděním. <a href="#ref-28">[28]</a>, <a href="#ref-14">[14]</a>
# - Půdní ekologie: mikrobiální respirace uhlíku. <a href="#ref-29">[29]</a>
# - Půdní ekologie: uhlíkový priming. <a href="#ref-30">[30]</a>
# - Půdní ekologie: uhlíkový priming se zpožděním. <a href="#ref-30">[30]</a>, <a href="#ref-14">[14]</a>
# - Půdní ekologie: transformace dusíku a N2O. <a href="#ref-31">[31]</a>
# - Půdní ekologie: denitrifikace řízená aerací. <a href="#ref-31">[31]</a>
# - Půdní ekologie: mikrobiální stechiometrie C–N. <a href="#ref-32">[32]</a>

# %% [markdown]
# <style>
# .jp-RenderedHTMLCommon h6[id^="ref-"],
# .text_cell_render h6[id^="ref-"] {
#   display: block !important;
#   height: 0 !important;
#   margin: 0 !important;
#   padding: 0 !important;
#   overflow: hidden !important;
#   line-height: 0 !important;
#   font-size: 0 !important;
# }
# </style>
# # References to HONU (selected)
#
# <style>
# h6[id^="ref-"] { margin: 0 !important; padding: 0 !important; height: 0 !important; overflow: hidden !important; }
# h6[id^="ref-"] .anchor-link { display: none !important; }
# </style>
#  <span style="display:none">ref-1</span>
# <span style="font-size:88%; line-height:1.25;">[1] P. M. Benes and I. Bukovsky, “Railway Wheelset Active Control and Stability via Higher Order Neural Units,” IEEE/ASME Trans. Mechatron., vol. 28, no. 5, pp. 2964–2975, Oct. 2023, doi: 10.1109/TMECH.2023.3258909.</span><br>
#  <span style="display:none">ref-2</span>
#
# <span style="font-size:88%; line-height:1.25;">[2] I. Bukovsky and N. Homma, “An Approach to Stable Gradient-Descent Adaptation of Higher-Order Neural Units,” <i>IEEE Transactions on Neural Networks and Learning Systems</i>, vol. 28, no. 9, pp. 2035–2046, Sep. 2017, doi: 10.1109/TNNLS.2016.2572310.</span>
#
#  <span style="display:none">ref-3</span>
# <span style="font-size:88%; line-height:1.25;">[3] I. Bukovsky, G. Dohnal, P. M. Benes, K. Ichiji, and N. Homma, “A Letter on Convergence of In-Parameter-Linear Nonlinear Neural Architectures with Gradient Learnings,” <i>IEEE Transactions on Neural Networks and Learning Systems</i>, vol. 34, no. 8, pp. 5189–5192, Aug. 2023, doi: 10.1109/TNNLS.2021.3123533.</span><br>
#  <span style="display:none">ref-4</span>
# <span style="font-size:88%; line-height:1.25;">[4] P. M. Benes, I. Bukovsky, M. Vesely, J. Voracek, K. Ichiji, and N. Homma, “Framework for Discrete-Time Model Reference Adaptive Control of Weakly Nonlinear Systems with HONUs,” in <i>Computational Intelligence</i>, Cham, Switzerland: Springer, 2019, pp. 239–262, doi: 10.1007/978-3-030-16469-0_13.</span><br>
#
# ## References for Simulated Plant Models
# <a id="ref-5"> </a>
# <span style="font-size:88%; line-height:1.25;">[5] F. Garcia-Ochoa and E. Gomez, “Bioreactor scale-up and oxygen transfer rate in microbial processes: An overview,” <i>Biotechnol. Adv.</i>, vol. 27, no. 2, pp. 153–176, Mar.–Apr. 2009, <a  href="https://doi.org/10.1016/j.biotechadv.2008.10.006" target="_blank" rel="noopener noreferrer">doi: 10.1016/j.biotechadv.2008.10.006</a>.</span><br>
#
#
# ###### <span style="display:none">ref-6</span>
# <span style="font-size:88%; line-height:1.25;">[6] W. Stumm and J. J. Morgan, <i>Aquatic Chemistry: Chemical Equilibria and Rates in Natural Waters</i>, 3rd ed. New York, NY, USA: Wiley, 1996, ISBN 978-0-471-51185-4. [Online]. Available: <a href="https://www.wiley.com/en-us/shop/general-chemistry/aquatic-chemistry-chemical-equilibria-and-rates-in-natural-waters-3rd-edition-p-9780471511854" target="_blank" rel="noopener noreferrer">Wiley</a>.</span><br>
# ###### <span style="display:none">ref-7</span>
# <span style="font-size:88%; line-height:1.25;">[7] J. Monod, “The growth of bacterial cultures,” <i>Annu. Rev. Microbiol.</i>, vol. 3, pp. 371–394, Oct. 1949, <a href="https://doi.org/10.1146/annurev.mi.03.100149.002103" target="_blank" rel="noopener noreferrer">doi: 10.1146/annurev.mi.03.100149.002103</a>.</span><br>
# ###### <span style="display:none">ref-8</span>
# <span style="font-size:88%; line-height:1.25;">[8] M. Gibaldi and D. Perrier, <i>Pharmacokinetics</i>, 2nd ed. New York, NY, USA: Marcel Dekker, 1982, <a href="https://doi.org/10.1201/b14095" target="_blank" rel="noopener noreferrer">doi: 10.1201/b14095</a>.</span><br>
# ###### <span style="display:none">ref-9</span>
# <span style="font-size:88%; line-height:1.25;">[9] L. B. Sheiner, D. R. Stanski, S. Vozeh, R. D. Miller, and J. Ham, “Simultaneous modeling of pharmacokinetics and pharmacodynamics: Application to d-tubocurarine,” <i>Clin. Pharmacol. Ther.</i>, vol. 25, no. 3, pp. 358–371, Mar. 1979, <a href="https://doi.org/10.1002/cpt1979253358" target="_blank" rel="noopener noreferrer">doi: 10.1002/cpt1979253358</a>.</span><br>
# ###### <span style="display:none">ref-10</span>
# <span style="font-size:88%; line-height:1.25;">[10] R. N. Bergman, I. D. Hope, Y. J. Yang, R. M. Watanabe, M. A. Meador, J. H. Youn, and M. Ader, “Assessment of insulin sensitivity in vivo: A critical review,” <i>Diabetes</i>, vol. 38, no. 12, pp. 1512–1527, Dec. 1989, <a href="https://doi.org/10.2337/diab.38.12.1512" target="_blank" rel="noopener noreferrer">doi: 10.2337/diab.38.12.1512</a>.</span><br>
# ###### <span style="display:none">ref-11</span>
# <span style="font-size:88%; line-height:1.25;">[11] D. M. Rowe, Ed., <i>Thermoelectrics Handbook: Macro to Nano</i>. Boca Raton, FL, USA: CRC Press, 2005, <a href="https://doi.org/10.1201/9781420038903" target="_blank" rel="noopener noreferrer">doi: 10.1201/9781420038903</a>.</span><br>
# ###### <span style="display:none">ref-12</span>
# <span style="font-size:88%; line-height:1.25;">[12] K. Skadron, M. R. Stan, K. Sankaranarayanan, W. Huang, S. Velusamy, and D. Tarjan, “Temperature-aware microarchitecture: Modeling and implementation,” <i>ACM Trans. Archit. Code Optim.</i>, vol. 1, no. 1, pp. 94–125, Mar. 2004, <a href="https://doi.org/10.1145/980152.980157" target="_blank" rel="noopener noreferrer">doi: 10.1145/980152.980157</a>.</span><br>
# ###### <span style="display:none">ref-13</span>
# <span style="font-size:88%; line-height:1.25;">[13] L. Kleinrock, <i>Queueing Systems, Volume I: Theory</i>. New York, NY, USA: Wiley, 1975, ISBN 978-0-471-49110-1. [Online]. Available: <a href="https://www.wiley.com/en-us/shop/general-introductory-statistics/queueing-systems-volume-i-p-9780471491101" target="_blank" rel="noopener noreferrer">Wiley</a>.</span><br>
# ###### <span style="display:none">ref-14</span>
# <span style="font-size:88%; line-height:1.25;">[14] T. K. S. Ritschel and J. Wyller, “An algorithm for distributed time delay identification based on a mixed Erlang kernel approximation and the linear chain trick,” <i>arXiv preprint arXiv:2405.07328</i>, 2024. [Online]. Available: <a href="https://arxiv.org/abs/2405.07328" target="_blank" rel="noopener noreferrer">arXiv</a>.</span><br>
# ###### <span style="display:none">ref-15</span>
# <span style="font-size:88%; line-height:1.25;">[15] C. V. Hollot, V. Misra, D. Towsley, and W. B. Gong, “Analysis and design of controllers for AQM routers supporting TCP flows,” <i>IEEE Trans. Autom. Control</i>, vol. 47, no. 6, pp. 945–959, Jun. 2002, <a href="https://doi.org/10.1109/TAC.2002.1008360" target="_blank" rel="noopener noreferrer">doi: 10.1109/TAC.2002.1008360</a>.</span><br>
# ###### <span style="display:none">ref-16</span>
# <span style="font-size:88%; line-height:1.25;">[16] C. E. Shannon, “A mathematical theory of communication,” <i>Bell Syst. Tech. J.</i>, vol. 27, no. 3, pp. 379–423, Jul. 1948, and vol. 27, no. 4, pp. 623–656, Oct. 1948, <a href="https://doi.org/10.1002/j.1538-7305.1948.tb01338.x" target="_blank" rel="noopener noreferrer">doi: 10.1002/j.1538-7305.1948.tb01338.x</a>.</span><br>
# ###### <span style="display:none">ref-17</span>
# <span style="font-size:88%; line-height:1.25;">[17] Feedback Instruments Ltd., <i>Coupled Tanks Control System: Instruction Manual</i>, model 33-041. [Online]. Available: <a href="https://tecnoedu.com/Download/33041SEd01.pdf" target="_blank" rel="noopener noreferrer">manual</a>.</span><br>
# ###### <span style="display:none">ref-18</span>
# <span style="font-size:88%; line-height:1.25;">[18] K. Ogata, <i>System Dynamics</i>, 4th ed. Upper Saddle River, NJ, USA: Pearson Prentice Hall, 2004, ISBN 978-0-13-142462-3. [Online]. Available: <a href="https://www.pearson.com/en-us/subject-catalog/p/system-dynamics/P200000003209/9780131424623" target="_blank" rel="noopener noreferrer">Pearson</a>.</span><br>
# ###### <span style="display:none">ref-19</span>
# <span style="font-size:88%; line-height:1.25;">[19] C. Canudas de Wit, H. Olsson, K. J. Åström, and P. Lischinsky, “A new model for control of systems with friction,” <i>IEEE Trans. Autom. Control</i>, vol. 40, no. 3, pp. 419–425, Mar. 1995, <a href="https://doi.org/10.1109/9.376053" target="_blank" rel="noopener noreferrer">doi: 10.1109/9.376053</a>.</span><br>
# ###### <span style="display:none">ref-20</span>
# <span style="font-size:88%; line-height:1.25;">[20] J. P. Den Hartog, <i>Mechanical Vibrations</i>, 4th ed. New York, NY, USA: McGraw-Hill, 1956, ISBN 978-0-07-016389-8. [Online]. Available: <a href="https://store.doverpublications.com/products/9780486647852" target="_blank" rel="noopener noreferrer">Dover</a>.</span><br>
# ###### <span style="display:none">ref-21</span>
# <span style="font-size:88%; line-height:1.25;">[21] P. C. Sen, <i>Principles of Electric Machines and Power Electronics</i>, 3rd ed. Hoboken, NJ, USA: Wiley, 2013, ISBN 978-1-118-07887-7. [Online]. Available: <a href="https://www.wiley.com/en-us/shop/general-introductory-electrical-electronics-engineering/principles-of-electric-machines-and-power-electronics-3rd-edition-p-9781118078877" target="_blank" rel="noopener noreferrer">Wiley</a>.</span><br>
# ###### <span style="display:none">ref-22</span>
# <span style="font-size:88%; line-height:1.25;">[22] E. M. Abdel-Rahman, A. H. Nayfeh, and Z. N. Masoud, “Dynamics and control of cranes: A review,” <i>J. Vib. Control</i>, vol. 9, no. 7, pp. 863–908, Jul. 2003, <a href="https://doi.org/10.1177/1077546303009007007" target="_blank" rel="noopener noreferrer">doi: 10.1177/1077546303009007007</a>.</span><br>
# ###### <span style="display:none">ref-23</span>
# <span style="font-size:88%; line-height:1.25;">[23] S. Bouabdallah, “Design and control of quadrotors with application to autonomous flying,” Ph.D. dissertation, École Polytechnique Fédérale de Lausanne, Lausanne, Switzerland, 2007, <a href="https://doi.org/10.5075/EPFL-THESIS-3727" target="_blank" rel="noopener noreferrer">doi: 10.5075/EPFL-THESIS-3727</a>.</span><br>
# ###### <span style="display:none">ref-24</span>
# <span style="font-size:88%; line-height:1.25;">[24] T. Schilcher, “Vector sum control of pulsed accelerating fields in Lorentz force detuned superconducting cavities,” Ph.D. dissertation, Univ. Hamburg, Hamburg, Germany, 1998. [Online]. Available: <a href="https://bib-pubdb1.desy.de/record/291638/" target="_blank" rel="noopener noreferrer">DESY PUBDB</a>.</span><br>
# ###### <span style="display:none">ref-25</span>
# <span style="font-size:88%; line-height:1.25;">[25] H. Wiedemann, <i>Particle Accelerator Physics</i>, 4th ed. Cham, Switzerland: Springer, 2015, <a href="https://doi.org/10.1007/978-3-319-18317-6" target="_blank" rel="noopener noreferrer">doi: 10.1007/978-3-319-18317-6</a>.</span><br>
# ###### <span style="display:none">ref-26</span>
# <span style="font-size:88%; line-height:1.25;">[26] P. Kundur, <i>Power System Stability and Control</i>. New York, NY, USA: McGraw-Hill, 1994, ISBN 978-0-07-035958-1. [Online]. Available: <a href="https://books.google.com/books?id=2cbvyf8Ly4AC" target="_blank" rel="noopener noreferrer">Google Books</a>.</span><br>
# ###### <span style="display:none">ref-27</span>
# <span style="font-size:88%; line-height:1.25;">[27] H. Bevrani, <i>Robust Power System Frequency Control</i>, 2nd ed. Cham, Switzerland: Springer, 2014, <a href="https://doi.org/10.1007/978-3-319-07278-4" target="_blank" rel="noopener noreferrer">doi: 10.1007/978-3-319-07278-4</a>.</span><br>
# ###### <span style="display:none">ref-28</span>
# <span style="font-size:88%; line-height:1.25;">[28] W. J. Parton, D. S. Schimel, C. V. Cole, and D. S. Ojima, “Analysis of factors controlling soil organic matter levels in Great Plains grasslands,” <i>Soil Sci. Soc. Am. J.</i>, vol. 51, no. 5, pp. 1173–1179, 1987, <a href="https://doi.org/10.2136/sssaj1987.03615995005100050015x" target="_blank" rel="noopener noreferrer">doi: 10.2136/sssaj1987.03615995005100050015x</a>.</span><br>
# ###### <span style="display:none">ref-29</span>
# <span style="font-size:88%; line-height:1.25;">[29] S. D. Allison, M. D. Wallenstein, and M. A. Bradford, “Soil-carbon response to warming dependent on microbial physiology,” <i>Nat. Geosci.</i>, vol. 3, pp. 336–340, 2010, <a href="https://doi.org/10.1038/ngeo846" target="_blank" rel="noopener noreferrer">doi: 10.1038/ngeo846</a>.</span><br>
# ###### <span style="display:none">ref-30</span>
# <span style="font-size:88%; line-height:1.25;">[30] Y. Kuzyakov, “Priming effects: Interactions between living and dead organic matter,” <i>Soil Biol. Biochem.</i>, vol. 42, no. 9, pp. 1363–1371, Sep. 2010, <a href="https://doi.org/10.1016/j.soilbio.2010.04.003" target="_blank" rel="noopener noreferrer">doi: 10.1016/j.soilbio.2010.04.003</a>.</span><br>
# ###### <span style="display:none">ref-31</span>
# <span style="font-size:88%; line-height:1.25;">[31] C. Li, S. Frolking, and T. A. Frolking, “A model of nitrous oxide evolution from soil driven by rainfall events: 1. Model structure and sensitivity,” <i>J. Geophys. Res.</i>, vol. 97, no. D9, pp. 9759–9776, 1992, <a href="https://doi.org/10.1029/92JG01691" target="_blank" rel="noopener noreferrer">doi: 10.1029/92JG01691</a>.</span><br>
# ###### <span style="display:none">ref-32</span>
# <span style="font-size:88%; line-height:1.25;">[32] R. L. Sinsabaugh, B. H. Hill, and J. J. F. Shah, “Ecoenzymatic stoichiometry of microbial organic nutrient acquisition in soil and sediment,” <i>Nature</i>, vol. 462, pp. 795–798, Dec. 2009, <a href="https://doi.org/10.1038/nature08632" target="_blank" rel="noopener noreferrer">doi: 10.1038/nature08632</a>.</span><br>

# %% [markdown]
# ---
#
# **Autor:** Ivo Bukovsky
# **Copyright © 2026 Ivo Bukovsky**
#
# Tato dokumentace a její původní obrázky jsou, není-li uvedeno jinak, licencovány pod licencí Creative Commons Attribution 4.0 International (CC BY 4.0).
